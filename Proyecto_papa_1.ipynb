# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from skimage import io
from google.colab.patches import cv2_imshow
import random
from numpy.core.numeric import array_equal
from numpy.lib import arrayterator
from math import pi

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
papa = cv2.imread('//content/drive/MyDrive/papa21.jpg')
papa = cv2.cvtColor(papa, cv2.COLOR_BGR2RGB)
plt.imshow(papa)
plt.show()

# %%
papa = cv2.imread('/content/drive/MyDrive/papa21.jpg')
gray =cv2.cvtColor(papa,cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray,(3,3),0)

thresh = cv2.adaptiveThreshold(blur,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,115,1)

contorno, _ = cv2.findContours(thresh, cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

filtered = []
for c in contorno:
  if cv2.contourArea(c) < 1000: continue
  filtered.append(c)
print("No Objetos Identificados")
print(len(filtered))
lienzo = np.zeros([papa.shape[0],papa.shape[1],3],'uint8')
for c in filtered:
  col = (random.randint(0,255), random.randint(0,255), random.randint(0,255))
  cv2.drawContours(lienzo,[c],-1,col, -1)
  area = cv2.contourArea(c)
  p = cv2.arcLength(c,True)
  
  
  print("Area",area, "Perimetro",p)
canny= cv2.Canny(lienzo, 10 , 180)


plt.imshow(lienzo)
plt.show()

plt.imshow(canny)
plt.show()
# Out:
# No Objetos Identificados
# 2
# Area 54821.0 Perimetro 1880.101716041565
# Area 5572.0 Perimetro 325.56348872184753
